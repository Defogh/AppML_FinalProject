# %%
from funcs.board_plotter import plot_board_single, plot_board_full

# %%
san = """
1. e4 c5 2. Nf3 Nc6 3. Bc4 e6
4. c3 b5 5. Bb3 c4 6. Bc2 a5
7. d4 cxd3 8. Qxd3 Nf6 9. e5 Nd5
10. Bg5 Qc7 11. Nbd2 h6 12. Bh4 Ba6
13. b3 Nf4 0-1
"""

# Static board after 10 half-moves.
plot_board_single(san, move_index=14)

# Interactive notebook viewer.
viewer = plot_board_full(san)
